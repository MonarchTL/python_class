# %%
pip install -U scikit-learn
# Out:
# ...
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/4e/ba/ce9bd1cd4953336a0e213b29cb80bb11816f2a93de8c99f88ef0b446ad0c/scikit_learn-1.3.2-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.2 MB 435.7 kB/s eta 0:00:22
#    ---------------------------------------- 0.0/9.2 MB 435.7 kB/s eta 0:00:22
#    ---------------------------------------- 0.0/9.2 MB 435.7 kB/s eta 0:00:22
#    ---------------------------------------- 0.1/9.2 MB 272.3 kB/s eta 0:00:34
#    ---------------------------------------- 0.1/9.2 MB 350.1 kB/s eta 0:00:27
#    ---------------------------------------- 0.1/9.2 MB 385.0 kB/s eta 0:00:24
#     --------------------------------------- 0.1/9.2 MB 387.0 kB/s eta 0:00:24
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Salary_data.csv', usecols = ['Salary','Job Title'])
dataset = dataset.dropna() #drop rows having empty value or NAN value
dataset
# Out:
#                          Job Title    Salary
# 0                Software Engineer   90000.0
# 1                     Data Analyst   65000.0
# 2                   Senior Manager  150000.0
# 3                  Sales Associate   60000.0
# 4                         Director  200000.0
# ..                             ...       ...
# 370       Senior Marketing Analyst   85000.0
# 371         Director of Operations  170000.0
# 372         Junior Project Manager   40000.0
# 373  Senior Operations Coordinator   90000.0
# 374        Senior Business Analyst  150000.0
#
# [373 rows x 2 columns]

# %%
# dataset[['Years of Experience']]
# Out:
#      Years of Experience
# 0                    5.0
# 1                    3.0
# 2                   15.0
# 3                    7.0
# 4                   20.0
# ..                   ...
# 370                  8.0
# 371                 19.0
# 372                  2.0
# 373                  7.0
# 374                 15.0
#
# [373 rows x 1 columns]

# %%
# dataset[['Years of Experience']].values
# Out:
# array([[ 5. ],
#        [ 3. ],
#        [15. ],
#        [ 7. ],
#        [20. ],
#        [ 2. ],
#        [12. ],
#        [ 4. ],
#        [ 1. ],
#        [10. ],
#        [ 3. ],
#        [18. ],
#        [ 6. ],
#        [14. ],
#        [ 2. ],
#        [16. ],
#        [ 7. ],
#        [12. ],
#        [ 0. ],
#        [22. ],
#        [ 5. ],
#        [19. ],
#        [ 2. ],
#        [ 9. ],
#        [13. ],
#        [ 3. ],
#        [11. ],
#        [ 1. ],
#        [15. ],
#        [ 6. ],
#        [25. ],
#        [ 4. ],
#        [ 3. ],
#        [10. ],
#        [20. ],
#        [ 2. ],
#        [ 7. ],
#        [14. ],
#        [ 1. ],
#        [21. ],
#        [ 5. ],
#        [18. ],
#        [ 3. ],
#        [ 8. ],
#        [13. ],
#        [ 2. ],
#        [ 5. ],
#        [16. ],
#        [11. ],
#        [ 0. ],
#        [22. ],
#        [ 7. ],
#        [12. ],
#        [19. ],
#        [ 3. ],
#        [ 9. ],
#        [ 2. ],
#        [17. ],
# ...

# %%
X =  dataset.iloc[:, 0:-1].values
X
# Out:
# array([['Software Engineer'],
#        ['Data Analyst'],
#        ['Senior Manager'],
#        ['Sales Associate'],
#        ['Director'],
#        ['Marketing Analyst'],
#        ['Product Manager'],
#        ['Sales Manager'],
#        ['Marketing Coordinator'],
#        ['Senior Scientist'],
#        ['Software Developer'],
#        ['HR Manager'],
#        ['Financial Analyst'],
#        ['Project Manager'],
#        ['Customer Service Rep'],
#        ['Operations Manager'],
#        ['Marketing Manager'],
#        ['Senior Engineer'],
#        ['Data Entry Clerk'],
#        ['Sales Director'],
#        ['Business Analyst'],
#        ['VP of Operations'],
#        ['IT Support'],
#        ['Recruiter'],
#        ['Financial Manager'],
#        ['Social Media Specialist'],
#        ['Software Manager'],
#        ['Junior Developer'],
#        ['Senior Consultant'],
#        ['Product Designer'],
#        ['CEO'],
#        ['Accountant'],
#        ['Data Scientist'],
# ...

# %%
Y =   dataset.iloc[:,1:].values
Y
# Out:
# array([[ 90000.],
#        [ 65000.],
#        [150000.],
#        [ 60000.],
#        [200000.],
#        [ 55000.],
#        [120000.],
#        [ 80000.],
#        [ 45000.],
#        [110000.],
#        [ 75000.],
#        [140000.],
#        [ 65000.],
#        [130000.],
#        [ 40000.],
#        [125000.],
#        [ 90000.],
#        [115000.],
#        [ 35000.],
#        [180000.],
#        [ 80000.],
#        [190000.],
#        [ 50000.],
#        [ 60000.],
#        [140000.],
#        [ 45000.],
#        [110000.],
#        [ 40000.],
#        [140000.],
#        [ 90000.],
#        [250000.],
#        [ 55000.],
#        [ 75000.],
#        [ 65000.],
#        [170000.],
#        [ 45000.],
#        [ 60000.],
#        [115000.],
#        [ 40000.],
#        [160000.],
#        [ 80000.],
#        [190000.],
#        [ 60000.],
#        [ 45000.],
#        [130000.],
#        [ 40000.],
#        [ 75000.],
#        [180000.],
#        [120000.],
#        [ 35000.],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, random_state = 1)

# %%
print(type(X_train[0][0]))
# Out:
# <class 'numpy.float64'>

# %%
# Training model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 4
#       2 from sklearn.linear_model import LinearRegression
#       3 model = LinearRegression()
# ----> 4 model.fit(X_train, Y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
#     676 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# ...

# %%
exp = float(input("Enter the years of experience:"))
exp = np.array([[exp]])
print(exp)

#predict the salary
predicted_salary = model.predict(exp)[0][0]
print("Your predicted year = ", predicted_salary)
# Out:
# Enter the years of experience:50
# [[50.]]
# Your predicted year =  371953.6089527868

# %%
predicted_salary = model.predict(X_test)
predicted_salary
# Out:
# array([[ 66556.28728712],
#        [ 39409.85869462],
#        [127635.75162025],
#        [ 59769.68013899],
#        [107275.93017588],
#        [ 46196.46584274],
#        [154782.18021276],
#        [168355.39450901],
#        [100489.32302775],
#        [ 52983.07299087],
#        [ 86916.1087315 ],
#        [ 46196.46584274],
#        [114062.537324  ],
#        [134422.35876838],
#        [ 46196.46584274],
#        [ 46196.46584274],
#        [141208.96591651],
#        [114062.537324  ],
#        [175142.00165714],
#        [ 52983.07299087],
#        [114062.537324  ],
#        [ 52983.07299087],
#        [120849.14447213],
#        [141208.96591651],
#        [134422.35876838],
#        [168355.39450901],
#        [ 80129.50158337],
#        [161568.78736088],
#        [ 46196.46584274],
#        [ 66556.28728712],
#        [175142.00165714],
#        [141208.96591651],
#        [ 42803.16226868],
#        [168355.39450901],
#        [ 52983.07299087],
# ...

# %%
plt.scatter(X_train, Y_train, color = 'blue')
plt.plot(X_train, model.predict(X_train), color = 'red')
plt.show()
