# %%
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup('https://www.worldometers.info/coronavirus/', 'html.parser')
soup = requests.get(url)
# Out:
# C:\Users\nisch\AppData\Local\Temp\ipykernel_5896\2974956766.py:3: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   url = BeautifulSoup('https://www.worldometers.info/coronavirus/', 'html.parser')

# %%
soup
# Out:
# <Response [200]>

# %%
code = BeautifulSoup(soup.text, 'lxml')
table_code = code.table
tags = table_code.find_all('tr')
data = []
for tag in tags:
    y = tag.text.split('\n')[1:]
    if y[0] != "":
        data.append(y)
# print(data)

# %%
import csv
file = open('covid_data.csv', 'w')
x = csv.writer(file)
x.writerows(data)
file.close()

# %%
import pandas as pd
df = pd.read_csv('covid_data.csv', encoding = 'latin1')
df
# Out:
#        #   Country,Other   TotalCases  NewCases  \
# 0      1             USA  110,025,396       NaN
# 1      2           India   45,008,620       NaN
# 2      3          France   40,138,560       NaN
# 3      4         Germany   38,751,299       NaN
# 4      5          Brazil   38,130,675       NaN
# ..   ...             ...          ...       ...
# 226  227         Tokelau           80       NaN
# 227  228    Vatican City           29       NaN
# 228  229  Western Sahara           10       NaN
# 229  230      MS Zaandam            9       NaN
# 230  231           China      503,302       NaN
#
#                                    TotalDeaths  NewDeaths TotalRecovered  \
# 0    1,189,943                                        NaN    107,796,954
# 1      533,333                                        NaN            NaN
# 2      167,642                                        NaN     39,970,918
# 3      179,854                                        NaN     38,240,600
# 4      708,237                                        NaN     36,249,161
# ..                                         ...        ...            ...
# 226                                                   NaN            NaN
# 227                                                   NaN             29
# 228          1                                        NaN              9
# 229          2                                        NaN              7
# 230      5,272                                        NaN        379,053
#
#     NewRecovered ActiveCases Serious,Critical  ...     Tests/  \
# 0            NaN   1,038,499            1,730  ...  3,543,990
# 1            NaN         NaN              NaN  ...    661,721
# 2            NaN           0              NaN  ...  4,139,547
# 3            NaN     330,845              NaN  ...  1,458,359
# 4            NaN   1,173,277              NaN  ...    296,146
# ..           ...         ...              ...  ...        ...
# 226          NaN          80              NaN  ...        NaN
# 227          NaN           0              NaN  ...        NaN
# 228          NaN           0              NaN  ...        NaN
# 229          NaN           0              NaN  ...        NaN
# 230          NaN     118,977              NaN  ...    110,461
#
#                                             1M pop        Unnamed: 15  \
# 0                                     334,805,269       North America
# 1                                   1,406,631,776                Asia
# 2                                      65,584,518              Europe
# 3                                      83,883,596              Europe
# 4                                     215,353,593       South America
# ..                                             ...                ...
# 226                                         1,378   Australia/Oceania
# 227                                           799              Europe
# 228                                       626,161              Africa
# 229                                                               NaN
# 230  1,448,471,400                                               Asia
#
#     Population      Continent  \
# 0          NaN          32810
# 1          NaN       312,6372
# 2          NaN          23910
# 3          NaN          24661
# 4          NaN          63043
# ..         ...            ...
# 226        NaN             17
# 227        NaN             28
# 228        NaN  62,616626,161
# 229        NaN            NaN
# 230        NaN  2,878274,7489
#
#     1 Caseevery X ppl1 Deathevery X ppl1 Testevery X ppl  New Cases/1M pop  \
# 0                                                  NaN                 NaN
# 1                                                  NaN                 NaN
# 2                                                  NaN                 NaN
# 3                                                  NaN                 NaN
# 4                                                  NaN                 NaN
# ..                                                 ...                 ...
# 226                                                NaN                 NaN
# 227                                                NaN                 NaN
# 228                                                NaN                 NaN
# 229                                                NaN                 NaN
# 230                                                NaN                 NaN
#
#     New Deaths/1M pop  Active Cases/1M pop  Unnamed: 22
# 0               3,102                  NaN          NaN
# 1                   3                  NaN          NaN
# 2                 NaN                  NaN          NaN
# 3               3,944                  NaN          NaN
# 4               5,448                  NaN          NaN
# ..                ...                  ...          ...
# 226            58,055                  NaN          NaN
# 227               NaN                  NaN          NaN
# 228               NaN                  NaN          NaN
# 229               NaN                  NaN          NaN
# 230                82                  NaN          NaN
#
# [231 rows x 23 columns]
