# %%
try:
    file = open('datas.csv','x')
    file.close()
except:
    print("File already exist")
# Out:
# File already exist

# %%
import pandas as pd
df = pd.read_csv('datas.csv')
df
# Out:
#    sn    name  age        add       phone
# 0   1     Ram   34  Kathmandu  9808778765
# 1   2   Shyam   23  Bhaktapur  9807656543
# 2   3  Laxmna   45   Birtamod  9875643543
# 3   4   Rabin   24   Sindhuli  9824356676
# 4   5   Manas   34     Balaju  9812345677
# 5   6   Akash   56      Jhapa  9808556543

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(3)
# Out:
#    sn    name  age        add       phone
# 0   1     Ram   34  Kathmandu  9808778765
# 1   2   Shyam   23  Bhaktapur  9807656543
# 2   3  Laxmna   45   Birtamod  9875643543

# %%
df.tail(3)
# Out:
#    sn   name  age       add       phone
# 3   4  Rabin   24  Sindhuli  9824356676
# 4   5  Manas   34    Balaju  9812345677
# 5   6  Akash   56     Jhapa  9808556543

# %%
df = pd.read_csv('datas.csv',index_col = 'sn')
df
# Out:
#       name  age        add       phone
# sn
# 1      Ram   34  Kathmandu  9808778765
# 2    Shyam   23  Bhaktapur  9807656543
# 3   Laxmna   45   Birtamod  9875643543
# 4    Rabin   24   Sindhuli  9824356676
# 5    Manas   34     Balaju  9812345677
# 6    Akash   56      Jhapa  9808556543

# %%
df.iloc[1:5]
# Out:
#       name  age        add       phone
# sn
# 2    Shyam   23  Bhaktapur  9807656543
# 3   Laxmna   45   Birtamod  9875643543
# 4    Rabin   24   Sindhuli  9824356676
# 5    Manas   34     Balaju  9812345677

# %%
df.loc[1:2]
# Out:
#      name  age        add       phone
# sn
# 1     Ram   34  Kathmandu  9808778765
# 2   Shyam   23  Bhaktapur  9807656543

# %%
df
# Out:
#       name  age        add       phone
# sn
# 1      Ram   34  Kathmandu  9808778765
# 2    Shyam   23  Bhaktapur  9807656543
# 3   Laxmna   45   Birtamod  9875643543
# 4    Rabin   24   Sindhuli  9824356676
# 5    Manas   34     Balaju  9812345677
# 6    Akash   56      Jhapa  9808556543

# %%
df['name'] == 'Ram'
# Out:
# sn
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# Name: name, dtype: bool

# %%
df[df['name'] == 'Ram']
# Out:
#    name  age        add       phone
# sn
# 1   Ram   34  Kathmandu  9808778765

# %%
data = df[(df['name'] == 'Ram') | (df['age'] < 25)]
data
# Out:
#      name  age        add       phone
# sn
# 1     Ram   34  Kathmandu  9808778765
# 2   Shyam   23  Bhaktapur  9807656543
# 4   Rabin   24   Sindhuli  9824356676

# %%
data.to_csv('data1.csv')

# %%
data = {'name':[],
        'age':[],
        'address':[]}
n = int(input("Enter the number of people:"))
for i in range(0,n):
    name = input("enter the name:")
    age = int(input(f"enter the age of {name}:"))
    address = input(f"Enter the address of {name}:")
    data['name'].append(name)
    data['age'].append(age)    
    data['address'].append(address)
# Out:
# Enter the number of people:3
# enter the name:Nischal
# enter the age of Nischal:23
# Enter the address of Nischal:kirtipur
# enter the name:Rabin
# enter the age of Rabin:24
# Enter the address of Rabin:balkumari
# enter the name:Bimisha
# enter the age of Bimisha:25
# Enter the address of Bimisha:Nakhipot
#       name  age    address
# 0  Nischal   23   kirtipur
# 1    Rabin   24  balkumari
# 2  Bimisha   25   Nakhipot

# %%
df = pd.DataFrame(data)
df
# Out:
#       name  age    address
# 0  Nischal   23   kirtipur
# 1    Rabin   24  balkumari
# 2  Bimisha   25   Nakhipot

# %%
data1 = {'name':['Ram','Shyam','Hari'],
         'age':['23','25','26'],
         'address':['kirtipur','Ktm','Dhn']}
print(data1)
data2 = {'name':['Ram','Shyam','Hari'],
         'age':['23','25','26'],
         'address':['kirtipur','Ktm','Dhn']}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
df = pd.concat([df1, df2])
df
# Out:
# {'name': ['Ram', 'Shyam', 'Hari'], 'age': ['23', '25', '26'], 'address': ['kirtipur', 'Ktm', 'Dhn']}
#     name age   address
# 0    Ram  23  kirtipur
# 1  Shyam  25       Ktm
# 2   Hari  26       Dhn
# 0    Ram  23  kirtipur
# 1  Shyam  25       Ktm
# 2   Hari  26       Dhn
